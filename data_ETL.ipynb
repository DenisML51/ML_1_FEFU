# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data_1.csv')
df.head()
# Out:
#    Unnamed: 0     price                                            address  \
# 0           0   4500000                Владивосток, Некрасовская улица, 52
# 1           1  10000000                    Владивосток, улица Нейбута, 139
# 2           2   6650000                      Владивосток, улица Лесная, 3д
# 3           3  11000000                    Владивосток, улица Леонова, 54к
# 4           4   4900000  Владивосток, Зелёный Бульвар, улица Зелёный Бу...
#
#    rooms  area  kitchen_area  floor     renovation          deal_type balcony  \
# 0    1.0  22.6           3.0    3.0  Косметический  Свободная продажа     нет
# 1    3.0  75.4           5.0    6.0           Евро                NaN     NaN
# 2    1.0  31.6           5.0    2.0    Отсутствует       Альтернатива     NaN
# 3    2.0  47.0           3.1    6.0    Отсутствует                NaN     NaN
# 4    1.0  24.1           3.0   16.0    Отсутствует                NaN     NaN
#
# ...

# %%
def transform_renovation(value):
    if pd.isna(value):
        return np.random.choice([0, 1]) 
    elif value == "Отсутствует":
        return 0
    else:
        return 1

df['renovation'] = df['renovation'].apply(transform_renovation)

# %%
def transform_deal_type(value):
    if pd.isna(value):
        return np.random.choice([0, 1])  
    elif value == "Свободная продажа":
        return 1
    elif value == "Альтернатива":
        return 0
    else:
        return np.random.choice([0, 1])  

df['deal_type'] = df['deal_type'].apply(transform_deal_type)

# %%
def transform_balcony(value):
    if pd.isna(value):
        return int(np.clip(np.round(np.random.normal(0.5, 0.2)), 0, 1))
    elif value == "нет":
        return 0
    else:
        return 1

df['balcony'] = df['balcony'].apply(transform_balcony)

# %%
def transform_trash_chute(value):
    if pd.isna(value) and np.random.rand() < 0.4:
        return np.nan
    elif pd.isna(value):
        return int(np.clip(np.round(np.random.normal(0.5, 0.2)), 0, 1))
    else:
        return 1 

df['trash_chute'] = df['trash_chute'].apply(transform_trash_chute)

# %%
df['trash_chute'].unique()
# Out:
# array([ 1., nan,  0.])

# %%
df['trash_chute'].unique()
# Out:
# array(['есть', nan], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 43 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Unnamed: 0                         120 non-null    int64
#  1   price                              120 non-null    int64
#  2   address                            120 non-null    object
#  3   rooms                              101 non-null    float64
#  4   area                               107 non-null    float64
#  5   kitchen_area                       89 non-null     float64
#  6   floor                              107 non-null    float64
#  7   renovation                         120 non-null    int64
#  8   deal_type                          120 non-null    int64
#  9   balcony                            120 non-null    int64
#  10  trash_chute                        83 non-null     float64
# ...

# %%
if 'Материал стен' in df.columns:
    df = pd.get_dummies(df, columns=['Материал стен'], prefix='wall_material')

# %%
if 'balcony' in df.columns and 'количество балконов' in df.columns:
    df.loc[(df['balcony'] == 0) & (df['количество балконов'].notna()) & (df['количество балконов'] != 0), 'balcony'] = 1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 43 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Unnamed: 0                         120 non-null    int64
#  1   price                              120 non-null    int64
#  2   address                            120 non-null    object
#  3   rooms                              101 non-null    float64
#  4   area                               107 non-null    float64
#  5   kitchen_area                       89 non-null     float64
#  6   floor                              107 non-null    float64
#  7   renovation                         120 non-null    int64
#  8   deal_type                          120 non-null    int64
#  9   balcony                            120 non-null    int64
#  10  trash_chute                        83 non-null     float64
# ...

# %%
if 'Лифт' in df.columns:
    df['Лифт'] = df['Лифт'].apply(lambda x: 1 if x == 'есть' else x)

# %%
df['Тип перекрытий'].unique()
# Out:
# array(['Железобетонный', nan, 'Монолитный', 'Смешанный', 'Иное',
#        'Деревянный'], dtype=object)

# %%
df
# Out:
#      Unnamed: 0     price                                            address  \
# 0             0   4500000                Владивосток, Некрасовская улица, 52
# 1             1  10000000                    Владивосток, улица Нейбута, 139
# 2             2   6650000                      Владивосток, улица Лесная, 3д
# 3             3  11000000                    Владивосток, улица Леонова, 54к
# 4             4   4900000  Владивосток, Зелёный Бульвар, улица Зелёный Бу...
# ..          ...       ...                                                ...
# 115         115   5000000                  Владивосток, улица Успенского, 18
# 116         116  11650000                  Владивосток, улица Басаргина, 6Бк
# 117         117   6500000                  Владивосток, улица Борисенко, 108
# 118         118   7000000                Владивосток, Светланская улица, 209
# 119         119   7200000            Владивосток, Фрегат, улица Ватутина, 4в
#
# ...

# %%
if 'address' in df.columns:
    df.drop(columns=['address'], inplace=True)

if 'Unnamed:0.1' in df.columns:
    df.drop(columns=['Unnamed:0.1'], inplace=True)

if 'Unnamed:0' in df.columns:
    df.drop(columns=['Unnamed:0'], inplace=True)

# %%
df.to_csv('data_3.csv')
